# %% [markdown]
# 제목,관객수(숫자),날짜,이미지 저장 >> 2020~2023 csv파일 저장 >> DataFrame으로 변경 > 관객수 최대값 관객수 최소값 관객수 평균 최대 관객수 5개 최소 관객수 5개를 출력
#
# C1021_10, c1025_02 참고
#
# 웹스크래핑 반드시 복습

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import csv
import pandas as pd

# %%
# 웹 스크래핑
for i in range(4):
    browser = webdriver.Chrome()
    url = f"https://search.daum.net/search?w=tot&q={i+2020}년영화순위&DA=MOR&rtmaxcoll=MOR"
    browser.get(url)
    time.sleep(5)
    soup = BeautifulSoup(browser.page_source,'lxml')
    with open(f'movie{i+2020}.html','w',encoding='utf8') as f:
        f.write(soup.prettify())
    browser.close()
print("저장완료")
# Out:
# 저장완료

# %%
# 데이터 추출
for i in range(4):
    with open(f"movie{i+2020}.html", "r", encoding="utf8") as f:
        soup = BeautifulSoup(f,'lxml')
        data = soup.select_one(
            "#mor_history_id_0 > div > div.flipsnap_view > div > div:nth-child(1) > c-flicking-item > c-layout > div > c-list-doc > ul"
        )
        movies = data.select("li")
    with open(f"movie{i+2020}.csv",'a',encoding='utf-8-sig',newline="") as ff:
        writer = csv.writer(ff)
        writer.writerow(["이미지링크","제목","관객수","날짜"])
        for movie in movies:
            img = movie.select_one('a.thumb_bf img')['src']
            # print(img)
            title = movie.select_one("strong.tit-g").text.strip()
            # print(title)
            num = movie.select_one("p.conts-desc").text.strip().replace(",", "")[3:-2]
            # print(num)
            date = movie.select_one("span.conts-subdesc").text.strip()
            # print(date)
            writer.writerow([img,title,num,date])
# Out:
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F2b07e0c665de4482b9a0094f66bc11761578025532290
# 남산의 부장들
# 475
# 2020.01.22.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F7a840d47e20d6a00f57194be307ea942e120bf03
# 다만 악에서 구하소서
# 435
# 2020.10.28.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F389d6e403d8ee48c419c7b16908919103e2c2670
# 반도
# 381
# 2020.07.15.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F23837d99576d43ba8e594f91497fea981579656331276
# 히트맨
# 240
# 2020.01.22.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F45ee167dd5a1fbbadc03af21dcba065324132c27
# 테넷
# 200
# 2020.08.26.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fc8555d7906ba4559a1290c616e416c4c1576742973513
# 백두산
# 825
# 2019.12.19.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F0695528a5d4f1daa2523e174d4566bbb50a880c2
# #살아있다
# 190
# 2020.06.24.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Ff6d6494aa78ac7ffde282c0e67b431beede65b91
# 강철비2: 정상회담
# 179
# 2020.09.30.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F0c2466f6f09ff51b8dee1c1a039aadb0d4adf991
# 담보
# 171
# 2020.09.29.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F8ed24b92bc0b4d5996bd94038034918c1577332236872
# 닥터 두리틀
# 160
# 2020.01.08.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F78b1640091eab12a09b8c2e881120e26993aecb1
# 모가디슈
# 361
# 2022.09.07.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Ff2d3ee4afbc78b44e34534037e17f7f382e1b65c
# 이터널스
# 305
# 2021.11.03.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Ff39274b0acd76f7c66f0a5fb9e5b7222ed37b373
# 블랙 위도우
# 296
# 2021.07.07.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Faa6aaf313fb192e6f77f5bd4490d5e127d707240
# 분노의 질주: 더 얼티메이트
# 229
# 2021.05.19.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F446090579974d44551356ce961743e57eaa41bd6
# 싱크홀
# 219
# 2021.08.11.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fe2733bbc22a93d16bace5658738322df204bbf01
# 극장판 귀멸의 칼날: 무한열차편
# 218
# 2022.04.21.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F4abb16fd8b2e51e518b7e0165633d4b9602f2495
# 베놈 2: 렛 데어 비 카니지
# 212
# 2021.10.13.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F71454256ae63506a7fee5e03cf929b9b65a4f433
# 소울
# 204
# 2021.01.20.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fa0fa0de4d943ad43edcae85122d8ee7e52ef60ea
# 크루엘라
# 198
# 2021.05.26.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F5a64941e61f5a3fbcad8ef6bbf7edb073b35c01a
# 샹치와 텐 링즈의 전설
# 174
# 2021.09.01.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F3f7e3035989e7918c6426e541c864d0d8a295de2
# 범죄도시2
# 1269
# 2022.05.18.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F4eb261668eb43a125d0adc250a89adb48216c005
# 탑건: 매버릭
# 823
# 2022.06.22.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F0cdb0abb3d8da8c6332bf6a945a86f9a32f67abd
# 아바타: 물의 길
# 1080
# 2022.12.14.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F2032840c034ca7a2536b55adabb0e8a5ca99dd83
# 한산: 용의 출현
# 726
# 2022.07.27.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F36f22dea0e0a9e0e626c549ce689558160c46ed4
# 공조2: 인터내셔날
# 698
# 2022.09.07.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fa645a5285e0758cc1fdff9b3aa72d5fb234a7fa9
# 닥터 스트레인지: 대혼돈의 멀티버스
# 588
# 2022.05.04.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F02ef8515570b2950e9f24d663cae807e7f40b5f2
# 헌트
# 435
# 2022.08.10.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F4899f10a714f3b1cb5bf9569f84e96df0020d414
# 올빼미
# 332
# 2022.11.23.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F5d3c3e6f0e2078681fb0f1a17240e901a8638bd3
# 쥬라기 월드: 도미니언
# 283
# 2022.06.01.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F9a03fb5ab29f3ae61de729ce21f42592f512cb23
# 마녀(魔女) Part2. The Other One
# 280
# 2022.06.15.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Ff47bdb7c3174e8bcf43fb6ab27283fc2f4d34555
# 서울의 봄
# 1312
# 2023.11.22.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fb05fec37909f3c46d8ada73ba1d2bc2f8868e869
# 범죄도시3
# 1068
# 2023.05.31.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fe4ce2c6ae33edb0ef32d5614b367f85c10a7316c
# 엘리멘탈
# 724
# 2023.06.14.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F3a684ccaeb7aeac8e3f060ffe7249f7fe039443a
# 스즈메의 문단속
# 557
# 2024.01.10.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F51a727081fdf0a5774f9e360f3ae3f15c85bc61d
# 밀수
# 514
# 2023.07.26.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fc370bb777da34359f244bed791ca2fa2f6e42298
# 더 퍼스트 슬램덩크
# 488
# 2023.01.04.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F6b0eb68a4c944965ae78c83112bbb799c25b876b
# 가디언즈 오브 갤럭시: Volume 3
# 420
# 2023.05.03.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fb65c5c7161099ca353e93f1e48115c7ef05dcaa8
# 미션 임파서블: 데드 레코닝 PART ONE
# 402
# 2023.07.12.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fce3dda655bc0eb73ffd6e82ba32e1bc6322b173a
# 콘크리트 유토피아
# 384
# 2023.08.09.
# https://search1.kakaocdn.net/thumb/R232x328.fwebp.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F0cdb0abb3d8da8c6332bf6a945a86f9a32f67abd
# 아바타: 물의 길
# 1080
# 2022.12.14.

# %%
# 데이터 불러오기
df1 = pd.read_csv('movie2020.csv',encoding='utf-8-sig')
df2 = pd.read_csv('movie2021.csv',encoding='utf-8-sig')
df3 = pd.read_csv('movie2022.csv',encoding='utf-8-sig')
df4 = pd.read_csv('movie2023.csv',encoding='utf-8-sig')
df = pd.concat([df1,df2,df3,df4])
# df 분석
df['관객수'].max() # 최대값
df['관객수'].min() # 최소값
df['관객수'].mean() # 평균
df['관객수'].nlargest(5) # 최대 5개
df['관객수'].nsmallest(5) # 최소 5개
# Out:
# 9    160
# 8    171
# 9    174
# 7    179
# 6    190
# Name: 관객수, dtype: int64
