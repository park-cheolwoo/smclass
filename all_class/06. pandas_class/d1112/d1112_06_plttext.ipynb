# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

matplotlib.rcParams["font.family"] = "Malgun Gothic"
matplotlib.rcParams["axes.unicode_minus"] = False
matplotlib.rcParams["font.size"] = 15

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.figure(figsize=(7,5))
plt.plot(x,y,label='범례데이터',marker="o")
# plt.text(x[0],y[0]+0.2,y[0], ha='center') # text(x좌표,y좌표,글자) ha : 글자를 가운데 정렬
# plt.text(x[1], y[1]+0.2, y[1], ha="center")  # text(x좌표,y좌표,글자)
# for
for idx,txt in enumerate(y):
  plt.text(x[idx]+0.05,y[idx]+0.2,y[idx],ha='center',color='red')


plt.title('라인그래프')
plt.legend()
plt.show()
