# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams["font.family"] = "Malgun Gothic"
matplotlib.rcParams["axes.unicode_minus"] = False
matplotlib.rcParams["font.size"] = 15

# %%
x = [-1, 2, 3]
y = [-2, -4, 8]
plt.plot(x, y)
plt.title("라인그래프 Line",loc='center',size=50) # size : 글자 크기 변경
plt.xlabel("X축 날짜", color="#e83420",loc='center')  # x축 설명 color : 글자색 변경/색상값,16진수 loc : 글자 위치(left/center/right)
plt.ylabel('Y축 인원', color='blue', loc='center') # y축 설명      # loc : top/center/bottom

## 그래프 눈금 표시
plt.xticks([1,2,3])
plt.yticks([2,4,8,9,10])
plt.show()
