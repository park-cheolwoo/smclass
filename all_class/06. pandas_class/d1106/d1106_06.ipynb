# %%
import pandas as pd

# %%
# DataFrame 변경해서
# '번호','이름','국어','영어','수학','합계','평균','등수'
# '번호','이름','합계','평균' 만 출력

1, 홍길동, 100, 100, 99, 299, 99.67, 0
2, 유관순, 80, 80, 85, 245, 81.67, 0
3, 이순신, 90, 90, 91, 271, 90.33, 0
4, 강감찬, 60, 65, 67, 192, 64.0, 0
5, 김구, 100, 100, 84, 284, 94.67, 0
6, 김유신, 80, 80, 71, 231, 77.0, 0
7, 홍길자, 100, 100, 90, 290, 96.66666666666667, 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 5
#       1 # DataFrame 변경해서
#       2 # '번호','이름','국어','영어','수학','합계','평균','등수'
#       3 # '번호','이름','합계','평균' 만 출력
# ----> 5 1, 홍길동, 100, 100, 99, 299, 99.67, 0
#       6 2, 유관순, 80, 80, 85, 245, 81.67, 0
#       7 3, 이순신, 90, 90, 91, 271, 90.33, 0
#
# NameError: name '홍길동' is not defined

# %%
data = {
    "번호": ["1", "2", "3", "4", "5", "6", "7"],
    "이름": ["홍길동", "유관순", "이순신", "강감찬", "김구", "김유신", "홍길자"],
    "국어": ["100", "80", "90", "60", "100", "80", "100"],
    "영어": ["100", "80", "90", "65", "100", "80", "100"],
    "수학": ["99", "85", "91", "67", "84", "71", "90"],
    "합계": ["299", "245", "271", "192", "284", "231", "290"],
    "평균": ["99.67", "81.67", "90.33", "64.0", "94.67", "77.0", "96.66666666666667"],
    "등수": [
        "0",
        "0",
        "0",
        "0",
        "0",
        "0",
        "0"
    ],
}
df = pd.DataFrame(data)
df.index = ["1번", "2번", "3번", "4번", "5번", "6번", "7번"]
df.index.name ='지원번호'
df
# Out:
#      번호   이름   국어   영어  수학   합계                 평균 등수
# 지원번호
# 1번    1  홍길동  100  100  99  299              99.67  0
# 2번    2  유관순   80   80  85  245              81.67  0
# 3번    3  이순신   90   90  91  271              90.33  0
# 4번    4  강감찬   60   65  67  192               64.0  0
# 5번    5   김구  100  100  84  284              94.67  0
# 6번    6  김유신   80   80  71  231               77.0  0
# 7번    7  홍길자  100  100  90  290  96.66666666666667  0

# %%
df.set_index("이름", inplace=True)  # reset이 아닌 set임에 유의
df
# Out:
#     번호   국어   영어  수학   합계                 평균 등수
# 이름
# 홍길동  1  100  100  99  299              99.67  0
# 유관순  2   80   80  85  245              81.67  0
# 이순신  3   90   90  91  271              90.33  0
# 강감찬  4   60   65  67  192               64.0  0
# 김구   5  100  100  84  284              94.67  0
# 김유신  6   80   80  71  231               77.0  0
# 홍길자  7  100  100  90  290  96.66666666666667  0

# %%
df.reset_index(inplace=True)
df
# Out:
#     이름 번호   국어   영어  수학   합계                 평균 등수
# 0  홍길동  1  100  100  99  299              99.67  0
# 1  유관순  2   80   80  85  245              81.67  0
# 2  이순신  3   90   90  91  271              90.33  0
# 3  강감찬  4   60   65  67  192               64.0  0
# 4   김구  5  100  100  84  284              94.67  0
# 5  김유신  6   80   80  71  231               77.0  0
# 6  홍길자  7  100  100  90  290  96.66666666666667  0

# %%
# set_index : 기존의 컬럼으로 index 설정
df.set_index('이름',inplace=True)
df
# Out:
#     번호   국어   영어  수학   합계                 평균 등수
# 이름
# 홍길동  1  100  100  99  299              99.67  0
# 유관순  2   80   80  85  245              81.67  0
# 이순신  3   90   90  91  271              90.33  0
# 강감찬  4   60   65  67  192               64.0  0
# 김구   5  100  100  84  284              94.67  0
# 김유신  6   80   80  71  231               77.0  0
# 홍길자  7  100  100  90  290  96.66666666666667  0

# %%
df[['번호','이름','합계','평균']]
# Out:
#      번호   이름   합계                 평균
# 지원번호
# 0     1  홍길동  299              99.67
# 1     2  유관순  245              81.67
# 2     3  이순신  271              90.33
# 3     4  강감찬  192               64.0
# 4     5   김구  284              94.67
# 5     6  김유신  231               77.0
# 6     7  홍길자  290  96.66666666666667

# %%
# sort 정렬
df.sort_index(inplace=True)
df.sort_index(ascending=False,inplace=True) # 역순정렬
df
# Out:
#     번호   국어   영어  수학   합계                 평균 등수
# 이름
# 홍길자  7  100  100  90  290  96.66666666666667  0
# 홍길동  1  100  100  99  299              99.67  0
# 이순신  3   90   90  91  271              90.33  0
# 유관순  2   80   80  85  245              81.67  0
# 김유신  6   80   80  71  231               77.0  0
# 김구   5  100  100  84  284              94.67  0
# 강감찬  4   60   65  67  192               64.0  0
