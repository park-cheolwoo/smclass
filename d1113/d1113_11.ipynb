# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np

matplotlib.rcParams["font.family"] = "Malgun Gothic"
matplotlib.rcParams["axes.unicode_minus"] = False
matplotlib.rcParams["font.size"] = 15

df = pd.read_excel('연령별인구현황_202410.xlsx',skiprows=3,usecols="B,E:Y",nrows=1,index_col='행정기관')
df
# Out:
#            0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국    1,276,904  1,888,125  2,327,761  2,297,634  2,676,856  3,321,756
#
#          30~34세     35~39세     40~44세     45~49세  ...     55~59세     60~64세  \
# 행정기관                                              ...
# 전국    3,471,857  3,140,777  3,924,653  3,832,876  ...  4,279,544  4,204,570
#
#          65~69세     70~74세     75~79세     80~84세   85~89세   90~94세  95~99세  \
# 행정기관
# 전국    3,578,969  2,371,155  1,771,888  1,344,879  757,029  265,052  58,536
#
#      100세 이상
# 행정기관
# 전국     8,644
#
# [1 rows x 21 columns]

# %%
# 연령별 인구피라미드 그리기
x = df.columns
# df.index
# df.rename({"전국  ":"전국"},inplace=True)
# df.loc['전국'] = df.loc['전국'].str.replace(",","").astype(int)/1000000
y = df.loc['전국'].values

plt.figure(figsize=(5,10))
plt.title('2024년 인구현황')
plt.xlabel('인구수(백만)')
plt.ylabel('연령대')
plt.barh(x,y,label='인구 수', color='skyblue')
plt.xlim(0,5)
for i in range(len(x)):
    plt.text(y[i] + 0.6, x[i], f"{y[i]*1000000:.0f}", ha="center", va="center")

# %%
# 남자, 여자 컬럼 복사
df.columns
plt.barh(x,-y,label='남자')
plt.barh(x,y2,label='여자')
plt.legend()

# %%
# 여자 현황 그래프 출력
df2 = pd.read_excel(
    "연령별인구현황_202410.xlsx",
    skiprows=3,
    usecols="B,AB:AV",
    nrows=1,
    index_col="행정기관",
)
x2 = df2.columns
df2.index
df2.rename({"전국  ":"전국"},inplace=True)
df2.loc['전국'] = df2.loc['전국'].str.replace(",","").astype(int)/1000000
y2 = df2.loc["전국"].values

plt.figure(figsize=(5, 10))
plt.barh(x2, y2, label="인구 수", color="pink")
plt.title("2024년 인구현황")
plt.xlabel("인구수(백만)")
plt.ylabel("연령대")
plt.xlim(0, 5)
for i in range (len(x2)):
    plt.text(y2[i]+0.6,x2[i],f"{y2[i]*1000000:.0f}",ha='center',va='center')
# Out:
# c:\python\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
#출산율 그래프를 출력하시오
df3 = pd.read_excel('출산율.xlsx',skiprows=2,nrows=1,index_col=0)
x = df3.columns
y = df3.loc['합계출산율'].values

plt.plot(x,y,'ko-')
plt.ylim(0,1.4)
plt.show()
# Out:
# c:\python\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
