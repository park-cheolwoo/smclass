# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np

matplotlib.rcParams["font.family"] = "Malgun Gothic"
matplotlib.rcParams["axes.unicode_minus"] = False
matplotlib.rcParams["font.size"] = 15

# %%
df = pd.read_excel('score.xlsx',index_col='지원번호')

# %%
plt.title('학생 성적 그래프')
plt.plot(df.index,df['국어'], label='국어')
plt.plot(df.index, df["영어"], label="영어")
plt.plot(df.index, df["수학"], label="수학")
for i in range (8):
  plt.text(df.index[i],df['국어'][i]+0.6,df['국어'][i],ha='center')
  plt.text(df.index[i],df['영어'][i]+0.6,df['영어'][i],ha='center')
  plt.text(df.index[i],df['수학'][i]+0.6,df['수학'][i],ha='center')

plt.legend()
plt.show()
# Out:
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_16896\1636720586.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(df.index[i],df['국어'][i]+0.6,df['국어'][i],ha='center')
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_16896\1636720586.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(df.index[i],df['영어'][i]+0.6,df['영어'][i],ha='center')
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_16896\1636720586.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(df.index[i],df['수학'][i]+0.6,df['수학'][i],ha='center')

# %%
# 누적 막대 그래프
plt.figure(figsize=(7,4))
plt.title("학생 성적 그래프")
plt.bar(df["이름"], df["국어"], width=0.6, label="국어")
plt.bar(df["이름"], df["영어"], bottom=df['국어'], width=0.6, label="영어")
plt.bar(df["이름"], df["수학"], bottom=(df["국어"] + df["영어"]), width=0.6, label='수학')
plt.legend()

for i in range(8):
  plt.text(df['이름'][i],df['국어'][i]-30,df['국어'][i],ha='center')
  plt.text(df['이름'][i],(df['영어'][i]+df['국어'][i])-30,df['영어'][i],ha='center')
  plt.text(df['이름'][i],(df['영어'][i]+df['국어'][i]+df['수학'][i])-30,df['수학'][i],ha='center')
# Out:
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_16896\2582523154.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(df['이름'][i],df['국어'][i]-30,df['국어'][i],ha='center')
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_16896\2582523154.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(df['이름'][i],(df['영어'][i]+df['국어'][i])-30,df['영어'][i],ha='center')
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_16896\2582523154.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(df['이름'][i],(df['영어'][i]+df['국어'][i]+df['수학'][i])-30,df['수학'][i],ha='center')

# %%
def n_func(x):
  if x-50>0:
    return x
  else : return 0


df['국어'].apply(n_func) # apply : pandas에서만 사용하는 문법
# Out:
# 지원번호
# 1번     90
# 2번      0
# 3번     80
# 4번      0
# 5번      0
# 6번     80
# 7번     55
# 8번    100
# Name: 국어, dtype: int64

# %%
idx = np.arange(8)
idx
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
.
w=0.25
plt.bar(idx-2*w,df['국어'],width=w)
plt.bar(idx-w,df['영어'],width=w)
plt.bar(idx,df['수학'],width=w)
# Out:
# <BarContainer object of 8 artists>
