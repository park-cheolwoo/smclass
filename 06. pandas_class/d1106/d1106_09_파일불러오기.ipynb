# %% [markdown]
# 파일 읽기

# %%
import pandas as pd

# csv 파일 읽기
# df = pd.read_csv('score.csv')
# df

# 2줄을 제외하고 가져옴
# df = pd.read_csv('score.csv',skiprows=2)
# df

# 1,3,5번째 줄을 제외하고 가져옴
# df = pd.read_csv('score.csv',skiprows=[1,3,5])
# df

# 지정된 개수만큼 출력
# index는 존재하고 아래에 있는 데이터 4개줄을 가져옴.
df = pd.read_csv('score.csv',nrows=4)
df
# Out:
#   지원번호   이름   학교    키  국어  영어   수학  사회        SW특기
# 0   1번  강나래  구로고  197  90  85  100  85      Python
# 1   2번  강태원  구로고  184  40  35   50  25        Java
# 2   3번  강호림  가산고  168  80  75   70  75  Javascript
# 3   4번  김수찬  구로고  187  40  60   70  80

# %% [markdown]
# 파일 읽기
# with read('score.csv','r') as f:

# %%
# txt 파일 읽기
# index 따로 지정이 되어 가져옴
# df = pd.read_csv('score.txt')
# \t를 구분자로 사용해서 가져오기
# df = pd.read_csv('score.txt',sep='\t')
# index 지정해서 가져오기
# df = pd.read_csv('score.txt',index_col='지원번호')
# 불러와서 index를 지정하기
df = pd.read_csv('score.txt')
df.set_index('지원번호',inplace=False)
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  사회        SW특기
# 0   1번  강나래  구로고  197   90   85  100  85      Python
# 1   2번  강태원  구로고  184   40   35   50  25        Java
# 2   3번  강호림  가산고  168   80   75   70  75  Javascript
# 3   4번  김수찬  구로고  187   40   60   70  80
# 4   5번  김재욱  가산고  188   15   20   10  10
# 5   6번  박동현  가산고  202   80  100   95  80           C
# 6   7번  박혜정  구로고  188   55   65   45  35      Python
# 7   8번  승근열  구로고  190  100   85   90  95          C#

# %% [markdown]
# 엑셀 파일 불러오기

# %%
# df = pd.read_excel('score.xlsx')

# # index 지정해서 불러오기
# df = pd.read_excel('score.xlsx',index_col='지원번호')

# df = pd.read_excel("score.xlsx",engine='openpyxl')
# df.set_index('지원번호',inplace=True)
# df
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[32], line 6
#       1 # df = pd.read_excel('score.xlsx')
#       2
#       3 # # index 지정해서 불러오기
#       4 # df = pd.read_excel('score.xlsx',index_col='지원번호')
# ----> 6 df = pd.read_excel("score.xlsx",engine='openpyxl')
#       7 df.set_index('지원번호',inplace=True)
#       8 df
#
# File c:\python\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
# ...
